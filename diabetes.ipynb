# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("C:/Users/MSI-NB/Desktop/Data science/Works/Pregrancy with Pregnancy/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df["Pregnancies"].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14],
#       dtype=int64)

# %%
df.groupby("Pregnancies").size()
# Out:
# Pregnancies
# 0     111
# 1     135
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 12      9
# 13     10
# 14      2
# 15      1
# 17      1
# dtype: int64

# %%
df["Glucose"].sort_values()
# Out:
# 75       0
# 502      0
# 349      0
# 342      0
# 182      0
#       ...
# 228    197
# 408    197
# 8      197
# 561    198
# 661    199
# Name: Glucose, Length: 768, dtype: int64

# %%
df = df.replace({"Glucose":{0: df["Glucose"].mean()}})

# %%
df.groupby("Glucose").size()
# Out:
# Glucose
# 44.0     1
# 56.0     1
# 57.0     2
# 61.0     1
# 62.0     1
#         ..
# 195.0    2
# 196.0    3
# 197.0    4
# 198.0    1
# 199.0    1
# Length: 136, dtype: int64

# %%
df["BloodPressure"].sort_values()
# Out:
# 347      0
# 494      0
# 222      0
# 81       0
# 78       0
#       ...
# 549    110
# 43     110
# 177    110
# 691    114
# 106    122
# Name: BloodPressure, Length: 768, dtype: int64

# %%
df = df.replace({"BloodPressure":{0:df["BloodPressure"].mean()}})

# %%
df.groupby("BloodPressure").size()
# Out:
# BloodPressure
# 24.000000      1
# 30.000000      2
# 38.000000      1
# 40.000000      1
# 44.000000      4
# 46.000000      2
# 48.000000      5
# 50.000000     13
# 52.000000     11
# 54.000000     11
# 55.000000      2
# 56.000000     12
# 58.000000     21
# 60.000000     37
# 61.000000      1
# 62.000000     34
# 64.000000     43
# 65.000000      7
# 66.000000     30
# 68.000000     45
# 69.105469     35
# 70.000000     57
# 72.000000     44
# 74.000000     52
# 75.000000      8
# 76.000000     39
# 78.000000     45
# 80.000000     40
# 82.000000     30
# 84.000000     23
# 85.000000      6
# 86.000000     21
# 88.000000     25
# 90.000000     22
# 92.000000      8
# 94.000000      6
# 95.000000      1
# 96.000000      4
# 98.000000      3
# 100.000000     3
# 102.000000     1
# 104.000000     2
# 106.000000     3
# 108.000000     2
# 110.000000     3
# 114.000000     1
# 122.000000     1
# dtype: int64

# %%
df["SkinThickness"].sort_values()
# Out:
# 686     0
# 201     0
# 683     0
# 578     0
# 207     0
#        ..
# 86     54
# 120    56
# 57     60
# 445    63
# 579    99
# Name: SkinThickness, Length: 768, dtype: int64

# %%
df = df.replace({"SkinThickness": {0 : df["SkinThickness"].mean()}})
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0      35.000000        0  33.6
# 1              1     85.0           66.0      29.000000        0  26.6
# 2              8    183.0           64.0      20.536458        0  23.3
# 3              1     89.0           66.0      23.000000       94  28.1
# 4              0    137.0           40.0      35.000000      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0      48.000000      180  32.9
# 764            2    122.0           70.0      27.000000        0  36.8
# 765            5    121.0           72.0      23.000000      112  26.2
# 766            1    126.0           60.0      20.536458        0  30.1
# 767            1     93.0           70.0      31.000000        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df["Insulin"].sort_values()
# Out:
# 0        0
# 443      0
# 440      0
# 439      0
# 438      0
#       ...
# 409    579
# 584    600
# 247    680
# 228    744
# 13     846
# Name: Insulin, Length: 768, dtype: int64

# %%
df = df.replace({"Insulin": {0: df["Insulin"].mean()}})
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df["BMI"].sort_values()
# Out:
# 145     0.0
# 706     0.0
# 522     0.0
# 49      0.0
# 371     0.0
#        ...
# 120    53.2
# 125    55.0
# 673    57.3
# 445    59.4
# 177    67.1
# Name: BMI, Length: 768, dtype: float64

# %%
df = df.replace({"BMI": {0: df["BMI"].mean()}})

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df["DiabetesPedigreeFunction"].sort_values()
# Out:
# 268    0.078
# 180    0.084
# 149    0.085
# 567    0.085
# 135    0.088
#        ...
# 45     1.893
# 370    2.137
# 4      2.288
# 228    2.329
# 445    2.420
# Name: DiabetesPedigreeFunction, Length: 768, dtype: float64

# %%
df["Age"].sort_values()
# Out:
# 255    21
# 60     21
# 102    21
# 182    21
# 623    21
#        ..
# 123    69
# 684    69
# 666    70
# 453    72
# 459    81
# Name: Age, Length: 768, dtype: int64

# %%
df["Outcome"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.groupby("Outcome").size()
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
#Diabetes vs Nondiabetes
sns.set_palette("colorblind")
plt.figure(figsize=(10,8))
plt.pie(df.groupby("Outcome").size(), autopct='%1.2f%%', labels=("Non-Diabetes","Diabetes"), colors=("Green", "Red"), radius=1, textprops={"size":"x-large", "fontweight":"bold"})
plt.title("Diabetes vs Non-Diabetes", fontsize=16, fontweight="bold")

plt.show()

# %%
#Pregnancies and Glucose Level
plt.figure(figsize=(12,6))
plt.plot(df.groupby("Pregnancies")["Glucose"].mean())
plt.title("Glucose level by Number Of Pregnancies", fontsize=18, fontweight="bold" )
plt.xticks(np.arange(0,18))
plt.xlabel("Number of Pregnancy", fontsize=13, fontweight="bold")
plt.ylabel("Glucose Level", fontsize=13, fontweight="bold")
# Out:
# Text(0, 0.5, 'Glucose Level')

# %%
#Glucose Level and Blood Preassure
plt.figure(figsize=(12,8))
scatter = plt.scatter(df["BloodPressure"], 
                df["Glucose"],
                alpha=0.8,
                c=df["Outcome"],
                cmap="viridis")
plt.legend(*scatter.legend_elements(),
                    loc="upper left",
                    title="Diabetes Status")
plt.xlabel("Blood Preassure", fontsize=13, fontweight="bold")
plt.ylabel("Glucose Level", fontsize=13, fontweight="bold")
plt.title("Blood Preassure - Glucose Level Relationship", fontsize=18, fontweight="bold")

plt.show()

# %%
#Glucose Insulin Relationship
plt.figure(figsize=(12,8))
scatter = plt.scatter(df["Glucose"],
            df["Insulin"],
            alpha=0.8,
            c=df["Outcome"],
            cmap="copper"
             )
plt.legend(*scatter.legend_elements(),
                    loc="upper left",
                    title="Diabetes Status")
plt.title("Glucose Insulin Level Relationship", fontsize=18, fontweight="bold")
plt.xlabel("Glucose Level", fontsize=13, fontweight="bold")
plt.ylabel("Insulin Level", fontsize=13, fontweight="bold")
# Out:
# Text(0, 0.5, 'Insulin Level')

# %%
#Diabetes Pedigree Glucose Level Relationship
plt.figure(figsize=(12,8))
scatter = plt.scatter(df["DiabetesPedigreeFunction"],
            df["Glucose"],
            alpha=0.8,
            c=df["Outcome"],
            cmap="PiYG")
plt.legend(*scatter.legend_elements(),
            loc="lower right",
            title="Diabetes Status")
plt.title("Diabetes Pedigree - Glucose Level Relationship", fontsize=18, fontweight="bold")
plt.xlabel("Diabetes Pedigree", fontsize=13, fontweight="bold")
plt.ylabel("Glucose Level", fontsize=13, fontweight="bold")
# Out:
# Text(0, 0.5, 'Glucose Level')

# %%
#BMI & Glucose Level Relationship
plt.figure(figsize=(12,8))
scatter = plt.scatter(df["BMI"],
            df["Glucose"],
            alpha=0.8,
            c=df["Outcome"],
            cmap="PiYG")
plt.legend(*scatter.legend_elements(),
            loc="lower right",
            title="Diabetes Status")
plt.title("BMI - Glucose Level Relationship", fontsize=18, fontweight="bold")
plt.xlabel("BMI", fontsize=13, fontweight="bold")
plt.ylabel("Glucose Level", fontsize=13, fontweight="bold")
# Out:
# Text(0, 0.5, 'Glucose Level')

# %%
#Age & Glucose Level Relationship
plt.figure(figsize=(12,8))
scatter = plt.scatter(df["Age"],
            df["Glucose"],
            alpha=0.8,
            c=df["Outcome"],
            cmap="PiYG")
plt.legend(*scatter.legend_elements(),
            loc="lower right",
            title="Diabetes Status")
plt.title("Age - Glucose Level Relationship", fontsize=18, fontweight="bold")
plt.xlabel("Age", fontsize=13, fontweight="bold")
plt.ylabel("Glucose Level", fontsize=13, fontweight="bold")
# Out:
# Text(0, 0.5, 'Glucose Level')
